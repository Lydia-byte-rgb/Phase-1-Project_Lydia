# %% [markdown]
# **#Phase 1 Project**
#
# Student Name: Lydia Mangoa
#
# Student Pace: Part-time DSF-PT09
#
# Project submission date: 24th November 2024
#
# Instructors: Noah Kandie & Bonface Manyara

# %% [markdown]
# # Project title: Evaluating Low-Risk Aircraft Models for Commercial and Private Operations

# %% [markdown]
# #1.**Overview**
#
# The goal of this analysis is to provide insights into aviation accidents to help identify low-risk aircraft models for commercial and private operations. This analysis will focus on:
#
# Accident frequencies by aircraft type and model.
#
# The number of engines on an aircraft and their influenc'e its safety performance and fatality rates
#
# Recommendations for selecting safer aircraft.

# %% [markdown]
# #2. **Business Understanding**

# %% [markdown]
# ##**Stakeholders**
#
# -Head of Aviation Division: Decision-maker for aircraft purchases.
#
# -Leadership Team: Interested in financial viability and risk minimization.

# %% [markdown]
# ##**Key Business Questions**
#
# Which aircraft models have the lowest accident rates?
#
# How does the number of engines on an aircraft influence its safety performance and fatality rates in commercial and high-stakes operations?
#
# How can accident trends inform the selection of low-risk aircraft?

# %% [markdown]
# ##**Source of Data**
# The dataset is sourced from the Kaggle Aviation Accident Database Synopses, which includes historical aviation accident data.

# %% [markdown]
# #3.**Data Understanding**

# %%
#Load the data set
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("./AviationData.csv", encoding="ISO-8859-1", low_memory=False)

# %%
#Summary of statistics
df.describe()
# Out:
#                           Event.Date   Latitude   Longitude  \
# count                          24670   7.000000    7.000000
# mean   1985-09-22 05:10:10.847182848  41.282976 -104.947540
# min              1948-10-24 00:00:00  30.757778 -173.240000
# 25%              1983-09-08 00:00:00  37.731111 -117.368611
# 50%              1985-07-19 00:00:00  42.445277  -88.355555
# 75%              1987-08-26 18:00:00  46.097777  -83.770834
# max              1990-01-02 00:00:00  48.120000  -70.758333
# std                              NaN   6.215394   34.987925
#
#        Number.of.Engines  Total.Fatal.Injuries  Total.Serious.Injuries  \
# count       24384.000000          24559.000000            24532.000000
# mean            1.159285              0.443259                0.204590
# min             0.000000              0.000000                0.000000
# 25%             1.000000              0.000000                0.000000
# 50%             1.000000              0.000000                0.000000
# 75%             1.000000              0.000000                0.000000
# max             4.000000            270.000000               47.000000
# std             0.470311              3.707189                0.720093
#
#        Total.Minor.Injuries  Total.Uninjured          Year  Severity.Score
# count          24527.000000     24582.000000  24670.000000         24670.0
# mean               0.336649         4.141608   1985.223956            -1.0
# min                0.000000         0.000000   1948.000000            -1.0
# 25%                0.000000         0.000000   1983.000000            -1.0
# 50%                0.000000         1.000000   1985.000000            -1.0
# 75%                0.000000         2.000000   1987.000000            -1.0
# max              125.000000       588.000000   1990.000000            -1.0
# std                1.549337        24.164961      2.297978             0.0

# %%
#Summary of data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24670 entries, 0 to 24692
# Data columns (total 34 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                24670 non-null  object
#  1   Investigation.Type      24670 non-null  object
#  2   Accident.Number         24670 non-null  object
#  3   Event.Date              24670 non-null  datetime64[ns]
#  4   Location                24663 non-null  object
#  5   Country                 24556 non-null  object
#  6   Latitude                7 non-null      float64
#  7   Longitude               7 non-null      float64
#  8   Airport.Code            12902 non-null  object
#  9   Airport.Name            14677 non-null  object
#  10  Injury.Severity         24670 non-null  object
#  11  Aircraft.damage         24670 non-null  object
#  12  Aircraft.Category       3607 non-null   object
#  13  Registration.Number     24665 non-null  object
#  14  Make                    24670 non-null  object
#  15  Model                   24670 non-null  object
#  16  Amateur.Built           24669 non-null  object
#  17  Number.of.Engines       24384 non-null  float64
#  18  Engine.Type             24666 non-null  object
#  19  FAR.Description         3607 non-null   object
#  20  Schedule                4052 non-null   object
#  21  Purpose.of.flight       24636 non-null  object
#  22  Air.carrier             1259 non-null   object
#  23  Total.Fatal.Injuries    24559 non-null  float64
#  24  Total.Serious.Injuries  24532 non-null  float64
#  25  Total.Minor.Injuries    24527 non-null  float64
#  26  Total.Uninjured         24582 non-null  float64
#  27  Weather.Condition       24670 non-null  object
#  28  Broad.phase.of.flight   24540 non-null  object
#  29  Report.Status           24670 non-null  object
#  30  Publication.Date        12228 non-null  object
#  31  Year                    24670 non-null  int32
#  32  Severity.Score          24670 non-null  float64
#  33  Is.Fatal                24670 non-null  bool
# dtypes: bool(1), datetime64[ns](1), float64(8), int32(1), object(23)
# memory usage: 6.3+ MB

# %%
#Quick overview -Showing the first five rows
df.head()
# Out:
#          Event.Id Investigation.Type Accident.Number Event.Date  \
# 0  20001218X45444           Accident      SEA87LA080 1948-10-24
# 1  20001218X45447           Accident      LAX94LA336 1962-07-19
# 2  20061025X01555           Accident      NYC07LA005 1974-08-30
# 3  20001218X45448           Accident      LAX96LA321 1977-06-19
# 4  20041105X01764           Accident      CHI79FA064 1979-08-02
#
#           Location        Country   Latitude  Longitude Airport.Code  \
# 0  MOOSE CREEK, ID  United States        NaN        NaN          NaN
# 1   BRIDGEPORT, CA  United States        NaN        NaN          NaN
# 2    Saltville, VA  United States  36.922223 -81.878056          NaN
# 3       EUREKA, CA  United States        NaN        NaN          NaN
# 4       Canton, OH  United States        NaN        NaN          NaN
#
#   Airport.Name  ... Total.Serious.Injuries Total.Minor.Injuries  \
# 0          NaN  ...                    0.0                  0.0
# 1          NaN  ...                    0.0                  0.0
# 2          NaN  ...                    NaN                  NaN
# 3          NaN  ...                    0.0                  0.0
# 4          NaN  ...                    2.0                  NaN
#
#   Total.Uninjured Weather.Condition Broad.phase.of.flight   Report.Status  \
# 0             0.0               UNK                Cruise  Probable Cause
# 1             0.0               UNK               Unknown  Probable Cause
# 2             NaN               IMC                Cruise  Probable Cause
# 3             0.0               IMC                Cruise  Probable Cause
# 4             0.0               VMC              Approach  Probable Cause
#
#   Publication.Date  Year Severity.Score Is.Fatal
# 0              NaN  1948           -1.0     True
# 1       19-09-1996  1962           -1.0     True
# 2       26-02-2007  1974           -1.0     True
# 3       12-09-2000  1977           -1.0     True
# 4       16-04-1980  1979           -1.0     True
#
# [5 rows x 34 columns]

# %%
#Quick overview- Showing the 5 last rows
df.tail()
# Out:
#              Event.Id Investigation.Type Accident.Number Event.Date  \
# 24688  20001213X29914           Accident      ATL90LA047 1989-12-29
# 24689  20001213X29900           Accident      ANC90LA023 1989-12-29
# 24690  20001213X29969           Accident      LAX90FA061 1989-12-30
# 24691  20001212X22389           Accident      CHI90LA059 1990-01-01
# 24692  20001212X22375           Accident      BFO90FA017 1990-01-02
#
#                 Location        Country  Latitude  Longitude Airport.Code  \
# 24688  WINSTON SALEM, NC  United States       NaN        NaN          NaN
# 24689         TANANA, AK  United States       NaN        NaN          NaN
# 24690         TUCSON, AZ  United States       NaN        NaN          TUS
# 24691        ELKHART, IN  United States       NaN        NaN          3C1
# 24692      BALTIMORE, MD  United States       NaN        NaN          BWI
#
#                  Airport.Name  ... Total.Serious.Injuries  \
# 24688                     NaN  ...                    1.0
# 24689                     NaN  ...                    0.0
# 24690            TUCSON INT'L  ...                    0.0
# 24691  MISHAWAKA PILOT'S CLUB  ...                    0.0
# 24692    BALTIMORE-WASHINGTON  ...                    3.0
#
#       Total.Minor.Injuries Total.Uninjured Weather.Condition  \
# 24688                  1.0             0.0               VMC
# 24689                  0.0             1.0               VMC
# 24690                 10.0           123.0               VMC
# 24691                  0.0             2.0               VMC
# 24692                  7.0           247.0               VMC
#
#       Broad.phase.of.flight   Report.Status Publication.Date  Year  \
# 24688                Cruise  Probable Cause       16-06-1992  1989
# 24689               Landing  Probable Cause       05-09-1990  1989
# 24690               Descent  Probable Cause       07-10-1992  1989
# 24691               Landing  Probable Cause       28-06-1991  1990
# 24692                Cruise         Probabl              NaN  1990
#
#       Severity.Score Is.Fatal
# 24688           -1.0    False
# 24689           -1.0    False
# 24690           -1.0    False
# 24691           -1.0    False
# 24692           -1.0    False
#
# [5 rows x 34 columns]

# %% [markdown]
# #4.**Data Preparation**

# %% [markdown]
# ###Clean Mixed-Type Columns
#
# Having received a warning while loading the data set that columns 6,7 and 28 have mixed datatypes, the first step will be to clean these columns.

# %%
print("Column names:", df.columns)
print("Columns with mixed types:")
print(df.iloc[:, [6, 7, 28]].head())
# Out:
# Column names: Index(['Event.Id', 'Investigation.Type', 'Accident.Number', 'Event.Date',
#        'Location', 'Country', 'Latitude', 'Longitude', 'Airport.Code',
#        'Airport.Name', 'Injury.Severity', 'Aircraft.damage',
#        'Aircraft.Category', 'Registration.Number', 'Make', 'Model',
#        'Amateur.Built', 'Number.of.Engines', 'Engine.Type', 'FAR.Description',
#        'Schedule', 'Purpose.of.flight', 'Air.carrier', 'Total.Fatal.Injuries',
#        'Total.Serious.Injuries', 'Total.Minor.Injuries', 'Total.Uninjured',
#        'Weather.Condition', 'Broad.phase.of.flight', 'Report.Status',
#        'Publication.Date', 'Year', 'Severity.Score', 'Is.Fatal'],
#       dtype='object')
# Columns with mixed types:
#     Latitude  Longitude Broad.phase.of.flight
# 0        NaN        NaN                Cruise
# 1        NaN        NaN               Unknown
# 2  36.922223 -81.878056                Cruise
# 3        NaN        NaN                Cruise
# 4        NaN        NaN              Approach

# %%
for col in [df.columns[6], df.columns[7], df.columns[28]]:
    print(f"Unique values in {col}:")
    print(df[col].unique())

    # Convert column to numeric (if needed), coercing errors to NaN
    df[col] = pd.to_numeric(df[col], errors="coerce")
# Out:
# Unique values in Latitude:
# [      nan 36.922223 42.445277 30.757778 46.041111 48.12     38.54
#  46.154444]
# Unique values in Longitude:
# [        nan  -81.878056  -70.758333  -88.355555 -120.849722 -113.8875
#  -173.24      -85.663611]
# Unique values in Broad.phase.of.flight:
# ['Cruise' 'Unknown' 'Approach' 'Climb' 'Takeoff' 'Landing' 'Taxi'
#  'Descent' 'Maneuvering' 'Standing' 'Go-around' 'Other' nan]

# %%
#Validate the data
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24670 entries, 0 to 24692
# Data columns (total 34 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                24670 non-null  object
#  1   Investigation.Type      24670 non-null  object
#  2   Accident.Number         24670 non-null  object
#  3   Event.Date              24670 non-null  datetime64[ns]
#  4   Location                24663 non-null  object
#  5   Country                 24556 non-null  object
#  6   Latitude                7 non-null      float64
#  7   Longitude               7 non-null      float64
#  8   Airport.Code            12902 non-null  object
#  9   Airport.Name            14677 non-null  object
#  10  Injury.Severity         24670 non-null  object
#  11  Aircraft.damage         24670 non-null  object
#  12  Aircraft.Category       3607 non-null   object
#  13  Registration.Number     24665 non-null  object
#  14  Make                    24670 non-null  object
#  15  Model                   24670 non-null  object
#  16  Amateur.Built           24669 non-null  object
#  17  Number.of.Engines       24384 non-null  float64
#  18  Engine.Type             24666 non-null  object
#  19  FAR.Description         3607 non-null   object
#  20  Schedule                4052 non-null   object
#  21  Purpose.of.flight       24636 non-null  object
#  22  Air.carrier             1259 non-null   object
#  23  Total.Fatal.Injuries    24559 non-null  float64
#  24  Total.Serious.Injuries  24532 non-null  float64
#  25  Total.Minor.Injuries    24527 non-null  float64
#  26  Total.Uninjured         24582 non-null  float64
#  27  Weather.Condition       24670 non-null  object
#  28  Broad.phase.of.flight   0 non-null      float64
#  29  Report.Status           24670 non-null  object
#  30  Publication.Date        12228 non-null  object
#  31  Year                    24670 non-null  int32
#  32  Severity.Score          24670 non-null  float64
#  33  Is.Fatal                24670 non-null  bool
# dtypes: bool(1), datetime64[ns](1), float64(9), int32(1), object(22)
# memory usage: 6.3+ MB
#                           Event.Date   Latitude   Longitude  \
# count                          24670   7.000000    7.000000
# mean   1985-09-22 05:10:10.847182848  41.282976 -104.947540
# min              1948-10-24 00:00:00  30.757778 -173.240000
# 25%              1983-09-08 00:00:00  37.731111 -117.368611
# 50%              1985-07-19 00:00:00  42.445277  -88.355555
# 75%              1987-08-26 18:00:00  46.097777  -83.770834
# max              1990-01-02 00:00:00  48.120000  -70.758333
# std                              NaN   6.215394   34.987925
#
#        Number.of.Engines  Total.Fatal.Injuries  Total.Serious.Injuries  \
# count       24384.000000          24559.000000            24532.000000
# mean            1.159285              0.443259                0.204590
# min             0.000000              0.000000                0.000000
# 25%             1.000000              0.000000                0.000000
# 50%             1.000000              0.000000                0.000000
# 75%             1.000000              0.000000                0.000000
# max             4.000000            270.000000               47.000000
# std             0.470311              3.707189                0.720093
#
#        Total.Minor.Injuries  Total.Uninjured  Broad.phase.of.flight  \
# count          24527.000000     24582.000000                    0.0
# mean               0.336649         4.141608                    NaN
# min                0.000000         0.000000                    NaN
# 25%                0.000000         0.000000                    NaN
# 50%                0.000000         1.000000                    NaN
# 75%                0.000000         2.000000                    NaN
# max              125.000000       588.000000                    NaN
# std                1.549337        24.164961                    NaN
#
#                Year  Severity.Score
# count  24670.000000         24670.0
# mean    1985.223956            -1.0
# min     1948.000000            -1.0
# 25%     1983.000000            -1.0
# 50%     1985.000000            -1.0
# 75%     1987.000000            -1.0
# max     1990.000000            -1.0
# std        2.297978             0.0

# %% [markdown]
# ###Handle Missing values

# %%
#Identify missing values
missing_data = df.isnull().sum()
print("Missing Values:\n", missing_data)
# Out:
# Missing Values:
#  Event.Id                      0
# Investigation.Type            0
# Accident.Number               0
# Event.Date                    0
# Location                      7
# Country                     114
# Latitude                  24663
# Longitude                 24663
# Airport.Code              11768
# Airport.Name               9993
# Injury.Severity               0
# Aircraft.damage               0
# Aircraft.Category         21063
# Registration.Number           5
# Make                          0
# Model                         0
# Amateur.Built                 1
# Number.of.Engines           286
# Engine.Type                   4
# FAR.Description           21063
# Schedule                  20618
# Purpose.of.flight            34
# Air.carrier               23411
# Total.Fatal.Injuries        111
# Total.Serious.Injuries      138
# Total.Minor.Injuries        143
# Total.Uninjured              88
# Weather.Condition             0
# Broad.phase.of.flight     24670
# Report.Status                 0
# Publication.Date          12442
# Year                          0
# Severity.Score                0
# Is.Fatal                      0
# dtype: int64

# %%
# Handle missing values
df['Aircraft.damage'] = df['Aircraft.damage'].fillna('Unknown')
df['Weather.Condition'] = df['Weather.Condition'].fillna('Unknown')

# Drop rows where 'Make' or 'Model' have missing values
df = df.dropna(subset=['Make', 'Model'])

# %% [markdown]
# # 5. **Data Analysis**

# %%
# Top 10 Aircraft Makes by Accident Count
top_makes = df['Make'].value_counts().head(10)

plt.figure(figsize=(10, 6))
top_makes.plot(kind='bar', color='skyblue')
plt.title("Top 10 Aircraft Makes by Accident Count")
plt.xlabel("Aircraft Make")
plt.ylabel("Number of Accidents")
plt.xticks(rotation=45)
plt.show()

# %%
# Top 10 Aircraft Models by Accident Count
plt.figure(figsize=(10, 6))
top_models.plot(kind='barh', color='red')  # 'barh' for horizontal bars
plt.title("Top 10 Aircraft Models by Accident Count")
plt.xlabel("Number of Accidents")
plt.ylabel("Aircraft Model")
plt.show()

# %%
# Yearly Trend in Accidents
# Ensure 'Event.Date' is in datetime format
df['Event.Date'] = pd.to_datetime(df['Event.Date'], errors='coerce')

# Extract the year from 'Event.Date'
df['Year'] = df['Event.Date'].dt.year

# Group data by year and count the number of accidents
yearly_accidents = df.groupby('Year').size()

# Plot the yearly trend of aviation accidents
plt.figure(figsize=(12, 6))
yearly_accidents.plot(kind='line', marker='o', color='red')
plt.title("Yearly Trend in Aviation Accidents")
plt.xlabel("Year")
plt.ylabel("Number of Accidents")
plt.grid(True)
plt.show()

# %%
# Plot showing the count of accidents by weather conditions
# Bar chart
weather_accidents = df['Weather.Condition'].value_counts()

plt.figure(figsize=(10, 6))
weather_accidents.plot(kind='bar', color='blue', label="Weather Conditions")

# Adding title and labels
plt.title("Accidents by Weather Conditions")
plt.xlabel("Weather Condition (e.g., Visual, Instrument, Unknown)")
plt.ylabel("Number of Accidents")
plt.xticks(rotation=45)
plt.legend()  # Adding a key (legend)
plt.show()

# %%
# Compare single-engine vs multi-engine accidents
# Severity mapping
severity_map = {
    "Fatal": 3,
    "Serious": 2,
    "Minor": 1,
    "None": 0,
    "Unknown": -1
}

# Apply severity mapping to create a severity score
df['Severity.Score'] = df['Injury.Severity'].map(severity_map).fillna(-1)

# Create a derived column to classify accidents as fatal or non-fatal
df['Is.Fatal'] = df['Total.Fatal.Injuries'] > 0

# Group by 'Number.of.Engines' to calculate fatality rates
engine_accidents = df.groupby('Number.of.Engines')['Is.Fatal'].mean()

# Plot the bar chart
plt.figure(figsize=(8, 5))
engine_accidents.plot(kind='bar', color=['green', 'orange'])
plt.title("Fatality Rate by Number of Engines")
plt.xlabel("Number of Engines")
plt.ylabel("Average Fatality Rate")
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# #6. **Conclusion**
# Key findings:
#
# -Aircraft Safety: Certain models (e.g., Cessna and piper) have a higher number of accidents but could reflect higher usage rather than risk.
#
# -Trends Over Tim e:Accident frequencies have declined over the years, indicating improving safety practices.
#
# -Fatality Rates by Number of Engi nes:Aircraft with multiple engines generally show lower average fatality rates compared to single-engine aircraft. This suggests that redundancy in engines enhances safety, potentially offering more options in emergencies, such as engine failure.

# %% [markdown]
# #7.Recommendations
# -Focus on Safe Aircraft Models: Prioritize modern, widely operated models with good safety records and low Severity Scores.
#
# -The declining trend in accidents likely reflects technological advancements. Prioritize acquiring modern aircraft models with the latest safety technologies (e.g., enhanced navigation systems, automated controls, and multi-engine redundancy). These investments align with reducing operational risks. Therefore' its safe to begin operations with aircraft models that have demonstrated lower accident rates historically.
#
# -Leverage Advanced Weather  Tech:Invest in aircraft equipped with advanced weather detection systems to handle adverse conditions effectively.
#
# -Choose Multi-Engine Aircraft for Commercial Operations: For commercial and high-stakes operations, prioritize acquiring multi-engine aircraft due to their lower fatality rates. This aligns with safety-first principles and enhances the company's reputation in aviation safety.
